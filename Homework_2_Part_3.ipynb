# %% [markdown]
# # Homework 2 Part 3

# %% [markdown]
# **Name:** Aida
#
# **Surname:** Martirosyan

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Problem 1**
#
# Create a DataFarme with titanic.csv file in your current directory.

# %%
df = pd.read_csv('titanic.csv')
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2    ?
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2       2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3      30      1      2  113781    151.55  C22 C26        S    ?  135
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %% [markdown]
# **Problem 2**
#
# Output all column datatypes of above DataFrame as a list.

# %%
a = list(df.dtypes)
a
# Out:
# [dtype('int64'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O')]

# %% [markdown]
# **Problem 3**
#
# Change the datatype of columns with 'int64' dtype to 'float64'.

# %%
for i in df.columns:
    if df[i].dtypes == "int64":
        df[i] = df[i].astype(float)

# %%
df.dtypes
# Out:
# pclass       float64
# survived     float64
# name          object
# sex           object
# age           object
# sibsp        float64
# parch        float64
# ticket        object
# fare          object
# cabin         object
# embarked      object
# boat          object
# body          object
# home.dest     object
# dtype: object

# %% [markdown]
# **Problem 4**
#
# Use describe function to output information about **all** columns in the DataDrame.

# %%
df.describe(include = "all")
# Out:
#              pclass     survived              name   sex   age        sibsp  \
# count   1309.000000  1309.000000              1309  1309  1309  1309.000000
# unique          NaN          NaN              1307     2    99          NaN
# top             NaN          NaN  Kelly, Mr. James  male     ?          NaN
# freq            NaN          NaN                 2   843   263          NaN
# mean       2.294882     0.381971               NaN   NaN   NaN     0.498854
# std        0.837836     0.486055               NaN   NaN   NaN     1.041658
# min        1.000000     0.000000               NaN   NaN   NaN     0.000000
# 25%        2.000000     0.000000               NaN   NaN   NaN     0.000000
# 50%        3.000000     0.000000               NaN   NaN   NaN     0.000000
# 75%        3.000000     1.000000               NaN   NaN   NaN     1.000000
# max        3.000000     1.000000               NaN   NaN   NaN     8.000000
#
#               parch    ticket  fare cabin embarked  boat  body home.dest
# count   1309.000000      1309  1309  1309     1309  1309  1309      1309
# unique          NaN       929   282   187        4    28   122       370
# top             NaN  CA. 2343  8.05     ?        S     ?     ?         ?
# freq            NaN        11    60  1014      914   823  1188       564
# mean       0.385027       NaN   NaN   NaN      NaN   NaN   NaN       NaN
# std        0.865560       NaN   NaN   NaN      NaN   NaN   NaN       NaN
# min        0.000000       NaN   NaN   NaN      NaN   NaN   NaN       NaN
# 25%        0.000000       NaN   NaN   NaN      NaN   NaN   NaN       NaN
# 50%        0.000000       NaN   NaN   NaN      NaN   NaN   NaN       NaN
# 75%        0.000000       NaN   NaN   NaN      NaN   NaN   NaN       NaN
# max        9.000000       NaN   NaN   NaN      NaN   NaN   NaN       NaN

# %% [markdown]
# **Problem 5**
#
# Set name column as the index and then reset the index with dropping. Perform those operations inplace.

# %%
df.set_index("name", inplace=True)

# %%
df.reset_index(drop = True, inplace=True)

# %% [markdown]
# **Reset changes**
#
# At this point, read the DataFrame again to undo all perviously made changes.

# %%
df = pd.read_csv('C://Users//Aida/Documents/titanic.csv')
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2    ?
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2       2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3      30      1      2  113781    151.55  C22 C26        S    ?  135
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %% [markdown]
# **Problem 6**
#
# Output the list of unqiue values in the DataFrame.

# %%
list({j for i in df for j in df[i].unique().tolist()})
# Out:
# [0,
#  1,
#  2,
#  3,
#  'Zimmerman, Mr. Leo',
#  4,
#  5,
#  6,
#  8,
#  9,
#  'Kink-Heilmann, Mrs. Anton (Luise Heilmann)',
#  'Rosblom, Mr. Viktor Richard',
#  '3101276',
#  'Shine, Miss. Ellen Natalia',
#  'Seattle, WA',
#  'Cardeza, Mr. Thomas Drake Martinez',
#  'Danbom, Mr. Ernst Gilbert',
#  'Allison, Miss. Helen Loraine',
#  '8.1375',
#  '28665',
#  'C D',
#  '334912',
#  '7.7417',
#  '8.0292',
#  '2659',
#  'Karun, Mr. Franz',
#  'Cribb, Mr. John Hatfield',
#  'Kink-Heilmann, Miss. Luise Gretchen',
#  'Moran, Mr. James',
#  'Becker, Mrs. Allen Oliver (Nellie E Baumgardner)',
#  'Oreskovic, Miss. Marija',
#  'C.A. 29395',
#  '25.4667',
#  'STON/O 2. 3101291',
#  'CA. 2343',
#  '229236',
#  '110813',
#  '13049',
#  '71.2833',
#  'Pennsylvania',
#  '342712',
#  'Lurette, Miss. Elise',
#  'Mitchell, Mr. Henry Michael',
#  'Haverford, PA / Cooperstown, NY',
#  '35281',
#  '347073',
#  'Rochester, NY',
#  'Andrews, Mr. Thomas Jr',
#  '10.1708',
#  '347063',
#  'Hart, Mr. Henry',
#  'Saalfeld, Mr. Adolphe',
#  'Peacock, Miss. Treasteall',
#  'Sheerlinck, Mr. Jan Baptist',
#  '244252',
#  'Carlsson, Mr. August Sigfrid',
#  'SOTON/O.Q. 3101305',
#  '31.6833',
#  '250649',
#  'C.A. 34651',
#  "Carr, Miss. Helen 'Ellen'",
#  'Jenkin, Mr. Stephen Curnow',
#  'West, Miss. Barbara J',
#  'Eklund, Mr. Hans Linus',
#  'E17',
#  '66',
#  'St Ives, Cornwall / Calumet, MI',
#  'Artagaveytia, Mr. Ramon',
#  'Trout, Mrs. William H (Jessie L)',
#  '367232',
#  'A9',
#  'Dulles, Mr. William Crothers',
#  '13508',
#  'Makinen, Mr. Kalle Edvard',
#  'Andrews, Miss. Kornelia Theodosia',
#  'PC 17601',
#  'B38',
#  'Mahon, Mr. John',
#  'Sandstrom, Miss. Marguerite Rut',
#  '110152',
#  'Backstrom, Mr. Karl Alfred',
#  '11',
#  "Brown, Miss. Amelia 'Mildred'",
#  'Bourke, Miss. Mary',
#  'Palsson, Master. Gosta Leonard',
#  '693',
#  '374746',
#  'van Melkebeke, Mr. Philemon',
#  'STON/O 2. 3101268',
#  'C 17369',
#  'Bystrom, Mrs. (Karolina)',
#  'Kallio, Mr. Nikolai Erland',
#  '113028',
#  '7.3125',
#  'E60',
#  'Gunnislake, England / Butte, MT',
#  '26707',
#  'Allison, Mrs. Hudson J C (Bessie Waldo Daniels)',
#  'Greenfield, Mr. William Bertram',
#  '230',
#  '2684',
#  'Chelsea, London',
#  '0.75',
#  'B82 B84',
#  '3101296',
#  'C23 C25 C27',
#  '16.1',
#  'Karun, Miss. Manca',
#  '57',
#  "Daly, Miss. Margaret Marcella 'Maggie'",
#  '34.0208',
#  'D22',
#  'McKane, Mr. Peter David',
#  'India / Rapid City, SD',
#  'C148',
#  'Spedden, Master. Robert Douglas',
#  'Douglas, Mrs. Frederick Charles (Mary Helene Baxter)',
#  'Mineff, Mr. Ivan',
#  'SC/Paris 2123',
#  '364856',
#  'Union Hill, NJ',
#  'Brewe, Dr. Arthur Jackson',
#  '382651',
#  '330844',
#  'Boulos, Mr. Hanna',
#  'PP 9549',
#  'Campbell, Mr. William',
#  '382650',
#  'Williams, Mr. Leslie',
#  'F33',
#  'Attalah, Miss. Malake',
#  '166',
#  '2692',
#  'Asplund, Master. Edvin Rojj Felix',
#  'Kingwilliamstown, Co Cork, Ireland New York, NY',
#  '2652',
#  'Hosono, Mr. Masabumi',
#  '151.55',
#  'Auburn, NY',
#  'A32',
#  '2699',
#  '2654',
#  '349238',
#  '236853',
#  'male',
#  'Brown, Miss. Edith Eileen',
#  'Hippach, Mrs. Louis Albert (Ida Sophia Fischer)',
#  'Slayter, Miss. Hilda Mary',
#  'Argentina',
#  'Denver, CO',
#  '112058',
#  '23.25',
#  'Samaan, Mr. Elias',
#  '695',
#  'Samaan, Mr. Hanna',
#  'Boulos, Master. Akar',
#  '36928',
#  '71',
#  'Sweden Akeley, MN',
#  'PC 17595',
#  'Johansson, Mr. Nils',
#  '345774',
#  'G6',
#  'Lundstrom, Mr. Thure Edvin',
#  "Assaf Khalil, Mrs. Mariana ('Miriam')",
#  'England Brooklyn, NY',
#  '7.7875',
#  '17453',
#  "O'Connell, Mr. Patrick D",
#  'Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)',
#  '2649',
#  'C.A. 17248',
#  'Sage, Mr. George John Jr',
#  'A. 2. 39186',
#  '2669',
#  'Devaney, Miss. Margaret Delia',
#  'Belfast',
#  'Mellors, Mr. William John',
#  'Sedgwick, Mr. Charles Frederick Waddington',
#  'Bournemouth, England Newark, NJ',
#  'Snyder, Mrs. John Pillsbury (Nelle Stevenson)',
#  'B19',
#  'Bourke, Mr. John',
#  'D43',
#  'Nicola-Yarred, Master. Elias',
#  'Laroche, Mrs. Joseph (Juliette Marie Louise Lafargue)',
#  'Petranec, Miss. Matilda',
#  '20.575',
#  'Giglio, Mr. Victor',
#  '370369',
#  'Austria',
#  'Endres, Miss. Caroline Louise',
#  '0.4167',
#  '30',
#  '330971',
#  '3101265',
#  'STON/O 2. 3101288',
#  'D40',
#  'Sweden Winnipeg, MN',
#  'Shaughnessy, Mr. Patrick',
#  'A/5 1478',
#  'Bryn Mawr, PA, USA',
#  'Elias, Mr. Joseph',
#  '79.65',
#  'Cleaver, Miss. Alice',
#  'Angle, Mr. William A',
#  'Asplund, Mr. Johan Charles',
#  'D30',
#  '345770',
#  'PC 17603',
#  'Scituate, MA',
#  '31028',
#  '345773',
#  'C52',
#  '386525',
#  'Paris / Haiti',
#  '111428',
#  '3101281',
#  'Lemberopolous, Mr. Peter L',
#  'Palsson, Master. Paul Folke',
#  'C28',
#  'Rice, Master. Eugene',
#  'PC 17759',
#  '173',
#  'Collander, Mr. Erik Gustaf',
#  'Stockholm, Sweden / Washington, DC',
#  'Geneva, Switzerland / Radnor, PA',
#  'Blackwell, Mr. Stephen Weart',
#  'Greensburg, PA',
#  'C6',
#  'Hoyt, Mr. William Fisher',
#  'F.C. 12750',
#  '350048',
#  'Brighton, MA',
#  '2651',
#  'C.A. 34644',
#  '15.0458',
#  '2671',
#  'D10 D12',
#  '350416',
#  'B3',
#  '349201',
#  '108.9',
#  'Folkstone, Kent / New York, NY',
#  "Khalil, Mrs. Betros (Zahie 'Maria' Elias)",
#  'West Hampstead, London / Neepawa, MB',
#  '349257',
#  '113803',
#  'Roebling, Mr. Washington Augustus II',
#  'Becker, Miss. Marion Louise',
#  '29108',
#  'E121',
#  'Barbara, Miss. Saiide',
#  '3101297',
#  '7553',
#  'E33',
#  'Austria-Hungary',
#  "Kelly, Mrs. Florence 'Fannie'",
#  'Louch, Mrs. Charles Alexander (Alice Adelaide Slow)',
#  'Canavan, Miss. Mary',
#  'PC 17592',
#  '376564',
#  'Russia New York, NY',
#  '237668',
#  '250653',
#  '7.875',
#  'Goodwin, Mrs. Frederick (Augusta Tyler)',
#  'Sweet, Mr. George Frederick',
#  'Penzance, Cornwall / Akron, OH',
#  'PC 17756',
#  'C.A. 15185',
#  "Mockler, Miss. Helen Mary 'Ellie'",
#  '237798',
#  'Whabee, Mrs. George Joseph (Shawneene Abi-Saab)',
#  'Tenglin, Mr. Gunnar Isidor',
#  'Cann, Mr. Ernest Charles',
#  '75.25',
#  'Sobey, Mr. Samuel James Hayden',
#  '248740',
#  'Pallas y Castello, Mr. Emilio',
#  '349243',
#  'Allen, Mr. William Henry',
#  'Lower Clapton, Middlesex or Erdington, Birmingham',
#  'Elias, Mr. Tannous',
#  'Larsson, Mr. Bengt Edvin',
#  '82.1708',
#  '113798',
#  'Cornwall / Spokane, WA',
#  'Bristol, England Cleveland, OH',
#  '51.8625',
#  'Williams, Mr. Charles Duane',
#  '32302',
#  'C54',
#  'Cook, Mrs. (Selena Rogers)',
#  'A14',
#  'Wirz, Mr. Albert',
#  'Crosby, Miss. Harriet R',
#  '2683',
#  'A23',
#  '315037',
#  'Hansen, Mr. Henry Damsgaard',
#  '349231',
#  'Rosblom, Miss. Salli Helena',
#  '330920',
#  'Troupiansky, Mr. Moses Aaron',
#  '76.7292',
#  'A/5 21175',
#  'Lines, Mrs. Ernest H (Elizabeth Lindsey James)',
#  'Colley, Mr. Edward Pomeroy',
#  'Fox, Mr. Stanley Hubert',
#  'Dean, Master. Bertram Vere',
#  'Holthen, Mr. Johan Martin',
#  '15.7417',
#  'Brooklyn, NY',
#  'Dodge, Mrs. Washington (Ruth Vidaver)',
#  'Appleton, Mrs. Edward Dale (Charlotte Lamson)',
#  'Asim, Mr. Adola',
#  'Khalil, Mr. Betros',
#  'Adams, Mr. John',
#  'Leonard, Mr. Lionel',
#  'Effington Rut, SD',
#  '312',
#  'SOTON/OQ 392090',
#  '315153',
#  'Liverpool, England Bedford, OH',
#  '7.7208',
#  "Hegarty, Miss. Hanora 'Nora'",
#  'Badman, Miss. Emily Louisa',
#  '13 15 B',
#  'Wick, Mr. George Dennick',
#  '350034',
#  'B61',
#  'C 7075',
#  'Borebank, Mr. John James',
#  '8.6625',
#  'Johanson, Mr. Jakob Alfred',
#  'Chaffee, Mr. Herbert Fuller',
#  '36568',
#  'Cornwall / Akron, OH',
#  'Wiklund, Mr. Karl Johan',
#  "Yrois, Miss. Henriette ('Mrs Harbeck')",
#  'Lingane, Mr. John',
#  'S.O./P.P. 2',
#  '27267',
#  '7.05',
#  'Peter, Miss. Anna',
#  '23.5',
#  'Tikkanen, Mr. Juho',
#  'Dowdell, Miss. Elizabeth',
#  '171',
#  '17465',
#  'Carlsson, Mr. Frans Olof',
#  '40',
#  '244270',
#  'Jacobsohn, Mr. Sidney Samuel',
#  '350036',
#  'Goldschmidt, Mr. George B',
#  '31418',
#  'PC 17607',
#  '307',
#  '223596',
#  '349252',
#  'SOTON/OQ 392089',
#  'W./C. 6608',
#  'F.C.C. 13528',
#  '188',
#  'Cherry, Miss. Gladys',
#  '2694',
#  'Kontiolahti, Finland / Detroit, MI',
#  'Hansen, Mr. Claus Peter',
#  'Reuchlin, Jonkheer. John George',
#  'Wilson, Miss. Helen Alice',
#  'Sharp, Mr. Percival James R',
#  'Spinner, Mr. Henry John',
#  'Myhrman, Mr. Pehr Fabian Oliver Malkolm',
#  '201',
#  'Manchester, England',
#  'D19',
#  'Yousif, Mr. Wazli',
#  'Graham, Mrs. William Thompson (Edith Junkins)',
#  '248747',
#  '231945',
#  '7.8',
#  'Klasen, Mrs. (Hulda Kristina Eugenia Lofqvist)',
#  'Ottawa, ON',
#  '2695',
#  'Liverpool / Montreal, PQ',
#  '28134',
#  'STON/O 2. 3101286',
#  'C91',
#  '45.5',
#  '19928',
#  'Nosworthy, Mr. Richard Cater',
#  '370376',
#  'Oreskovic, Miss. Jelka',
#  'Drazenoic, Mr. Jozef',
#  '113790',
#  '364516',
#  'Southsea, Hants',
#  "Ryerson, Miss. Susan Parker 'Suzette'",
#  'Detroit, MI',
#  'Head, Mr. Christopher',
#  'Q',
#  'Cincinatti, OH',
#  '347076',
#  'C.A. 33111',
#  '239855',
#  '2696',
#  '2621',
#  'Olsen, Mr. Ole Martin',
#  'Cornwall / Clear Creek, CO',
#  'Portugal / Sau Paulo, Brazil',
#  'A/5 3536',
#  'Davis, Miss. Mary',
#  '365226',
#  'A/5 3594',
#  'Tomlin, Mr. Ernest Portage',
#  'PC 17613',
#  'Giles, Mr. Edgar',
#  "Wells, Mrs. Arthur Henry ('Addie' Dart Trevaskis)",
#  'F',
#  'Abbott, Mr. Rossmore Edward',
#  'Nieminen, Miss. Manta Josefina',
#  '43',
#  '349210',
#  '40.125',
#  'D7',
#  'Sweden Chicago, IL',
#  'Amenia, ND',
#  '7.925',
#  'Ryan, Mr. Edward',
#  'Trenton, NJ',
#  'Connolly, Miss. Kate',
#  '9.8375',
#  'Stanley, Miss. Amy Zillah Elsie',
#  '7538',
#  'Goncalves, Mr. Manuel Estanslas',
#  '26.55',
#  '12233',
#  'Navratil, Master. Edmond Roger',
#  'Dean, Mr. Bertram Frank',
#  '96',
#  'Harmer, Mr. Abraham (David Lishin)',
#  '349251',
#  'Panula, Master. Urho Abraham',
#  '358585',
#  '250651',
#  'Co Limerick, Ireland Sherbrooke, PQ',
#  'Lahoud, Mr. Sarkis',
#  'Pain, Dr. Alfred',
#  'Johnson, Mr. William Cahoone Jr',
#  '36866',
#  '7.65',
#  'Bulgaria Chicago, IL',
#  '680',
#  '2650',
#  'Peacock, Master. Alfred Edward',
#  'Waelens, Mr. Achille',
#  'Daher, Mr. Shedid',
#  '2627',
#  '239865',
#  'Razi, Mr. Raihed',
#  '228414',
#  '347085',
#  'Clarke, Mrs. Charles V (Ada Maria Winfield)',
#  '13502',
#  'W/C 14208',
#  'Emanuel, Miss. Virginia Ethel',
#  'Devonport, England',
#  '28403',
#  'Bjorklund, Mr. Ernst Herbert',
#  '330980',
#  'Italy Philadelphia, PA',
#  'Fa 265302',
#  'Calderhead, Mr. Edward Pennington',
#  '113054',
#  '287',
#  'SC/PARIS 2147',
#  '349242',
#  'Spencer, Mr. William Augustus',
#  '2661',
#  'Webber, Miss. Susan',
#  'Seattle, WA / Toledo, OH',
#  'McCrae, Mr. Arthur Gordon',
#  'Saade, Mr. Jean Nassr',
#  '11752',
#  'SC 14888',
#  'Samaan, Mr. Youssef',
#  '349219',
#  'Barre, Co Washington, VT',
#  'Widener, Mrs. George Dunton (Eleanor Elkins)',
#  'Penasco y Castellana, Mrs. Victor de Satode (Maria Josefa Perez de Soto y Vallejo)',
#  'Peter, Mrs. Catherine (Catherine Rizk)',
#  'Smyth, Miss. Julia',
#  '349223',
#  'C47',
#  "Williams, Mr. Howard Hugh 'Harry'",
#  'Nesson, Mr. Israel',
#  'Carver, Mr. Alfred John',
#  '1',
#  'S.O./P.P. 3',
#  '374887',
#  "O'Connor, Mr. Patrick",
#  '113505',
#  '364848',
#  'Goodwin, Master. Sidney Leonard',
#  'Southampton',
#  'B45',
#  'Ireland New York, NY',
#  'SOTON/OQ 392076',
#  '211535',
#  'E63',
#  'White, Mrs. John Stuart (Ella Holmes)',
#  '7.725',
#  'F.C.C. 13534',
#  '149',
#  'Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genevieve Fosdick)',
#  'Isham, Miss. Ann Elizabeth',
#  '3101278',
#  'Smith, Miss. Marion Elsie',
#  'Salo, Finland Astoria, OR',
#  'Hays, Mrs. Charles Melville (Clara Jennings Gregg)',
#  'Nancarrow, Mr. William Henry',
#  '237736',
#  'E46',
#  'Lindahl, Miss. Agda Thorilda Viktoria',
#  'Watt, Miss. Bertha J',
#  'Rice, Master. George Hugh',
#  'Andersson, Mrs. Anders Johan (Alfrida Konstantia Brogren)',
#  'A4. 54510',
#  'White, Mr. Richard Frasar',
#  '2657',
#  '3410',
#  'E49',
#  'Vander Cruyssen, Mr. Victor',
#  'Dennis, Mr. William',
#  '6.2375',
#  'England / Bennington, VT',
#  'Haddenfield, NJ',
#  'C.A. 33112',
#  '364846',
#  'F.C.C. 13540',
#  'Asplund, Master. Filip Oscar',
#  'Kalvik, Mr. Johannes Halvorsen',
#  'Thorneycroft, Mrs. Percival (Florence Kate White)',
#  'Lewy, Mr. Ervin G',
#  'de Messemaeker, Mrs. Guillaume Joseph (Emma)',
#  'Kraeff, Mr. Theodor',
#  'Olsson, Mr. Nils Johan Goransson',
#  'Jarvis, Mr. John Denzil',
#  'Lundahl, Mr. Johan Svensson',
#  'Malachard, Mr. Noel',
#  '28034',
#  'New York, NY / Washington, DC',
#  'del Carlo, Mr. Sebastiano',
#  '299',
#  'Connaghton, Mr. Michael',
#  'Caldwell, Mr. Albert Francis',
#  'Worcester, MA',
#  'Cumings, Mr. John Bradley',
#  'London / Staten Island, NY',
#  'Lindqvist, Mr. Eino William',
#  '29105',
#  '220845',
#  '363294',
#  'Rotherfield, Sussex, England Essex Co, MA',
#  'F.C. 12998',
#  'Cornell, Mrs. Robert Clifford (Malvina Helen Lamson)',
#  '15.9',
#  'Becker, Miss. Ruth Elizabeth',
#  '25.5875',
#  'PC 17569',
#  'Hassan, Mr. Houssein G N',
#  'Giles, Mr. Frederick Edward',
#  'Simmons, Mr. John',
#  'Ware, Mr. Frederick',
#  'E39 E41',
#  'Braf, Miss. Elin Ester Maria',
#  'Astor, Col. John Jacob',
#  '15.0333',
#  'Frauenthal, Dr. Henry William',
#  'D45',
#  'Oskarshamn, Sweden Minneapolis, MN',
#  'Ohman, Miss. Velin',
#  'Beesley, Mr. Lawrence',
#  'St Austall, Cornwall',
#  '14',
#  '112378',
#  'A5',
#  '169',
#  '347467',
#  'Birkdale, England Cleveland, Ohio',
#  '7.2292',
#  'C 17368',
#  'Skoog, Miss. Mabel',
#  '69',
#  'A/5 21172',
#  '29751',
#  'London / Paris',
#  'Hays, Miss. Margaret Bechstein',
#  'Williams, Mr. Charles Eugene',
#  'Andersson, Miss. Ellis Anna Maria',
#  'Madsen, Mr. Fridtjof Arne',
#  'Thomas, Mr. Charles P',
#  'Hanna, Mr. Mansour',
#  '33',
#  '315087',
#  'Chevre, Mr. Paul Romaine',
#  '101',
#  'Calic, Mr. Petar',
#  '8 10',
#  'Longley, Miss. Gretchen Fiske',
#  'Plymouth, Dorset / Houghton, MI',
#  'A/5 2466',
#  '347069',
#  'Austria Niagara Falls, NY',
#  '383121',
#  'Montreal, PQ',
#  '19.9667',
#  'Duane, Mr. Frank',
#  'A/5 21174',
#  '15.85',
#  'Haas, Miss. Aloisia',
#  'Davies, Mr. John Samuel',
#  'Silverthorne, Mr. Spencer Victor',
#  'E68',
#  'Jermyn, Miss. Annie',
#  'E8',
#  'Kink, Miss. Maria',
#  'Maenpaa, Mr. Matti Alexanteri',
#  'Renouf, Mr. Peter Henry',
#  'PC 17485',
#  'Somerton, Mr. Francis William',
#  'Fortune, Mrs. Mark (Mary McDougald)',
#  'Kreuchen, Miss. Emilie',
#  'Montvila, Rev. Juozas',
#  '7552',
#  '350046',
#  'Johansson, Mr. Erik',
#  'C30',
#  'Risien, Mrs. Samuel (Emma)',
#  'London / Birmingham',
#  '3460',
#  '349247',
#  'Padro y Manent, Mr. Julian',
#  '29106',
#  '6.975',
#  'B73',
#  '20.2125',
#  'Peruschitz, Rev. Joseph Maria',
#  'A/5. 851',
#  '36864',
#  'C53',
#  '233478',
#  'Bath, England / Massachusetts',
#  '315084',
#  'Olsson, Miss. Elina',
#  'SOTON/OQ 3101317',
#  'Sinkkonen, Miss. Anna',
#  '394140',
#  'C70',
#  'Gibson, Mrs. Leonard (Pauline C Boeson)',
#  '12.275',
#  '312992',
#  '7.2833',
#  'Albany, NY',
#  '110465',
#  'Chronopoulos, Mr. Apostolos',
#  '220367',
#  "McNamee, Mrs. Neal (Eileen O'Leary)",
#  '349220',
#  'Reeves, Mr. David',
#  'Douglas, Mr. Walter Donald',
#  '12.2875',
#  '5',
#  'E24',
#  '68',
#  'Klaber, Mr. Herman',
#  'Taussig, Miss. Ruth',
#  'Minahan, Dr. William Edward',
#  'Rugg, Miss. Emily',
#  '52',
#  'Omont, Mr. Alfred Fernand',
#  '330877',
#  'Denmark Hill, Surrey / Chicago',
#  'Dintcheff, Mr. Valtcho',
#  '349912',
#  '57.9792',
#  '80',
#  '250648',
#  'Nice, France',
#  '11813',
#  'Robbins, Mr. Victor',
#  '55',
#  '244310',
#  'London Brooklyn, NY',
#  'Bryhl, Miss. Dagmar Jenny Ingeborg',
#  '28666',
#  'Ringhini, Mr. Sante',
#  '196',
#  'SC/PARIS 2146',
#  'Portland, OR',
#  'Jones, Mr. Charles Cresson',
#  'PC 17599',
#  'Celotti, Mr. Francesco',
#  'Gronnestad, Mr. Daniel Danielsen',
#  'C124',
#  'Lefebre, Miss. Jeannie',
#  'Pedersen, Mr. Olaf',
#  'Peacock, Mrs. Benjamin (Edith Nile)',
#  'A.5. 3236',
#  '28425',
#  'Karberg, Sweden Jerome Junction, AZ',
#  'Payne, Mr. Vivian Ponsonby',
#  'Nicholson, Mr. Arthur Ernest',
#  'Maybery, Mr. Frank Hubert',
#  'Buss, Miss. Kate',
#  'Abbott, Mrs. Stanton (Rosa Hunt)',
#  'Greenfield, Mrs. Leo David (Blanche Strouse)',
#  'SOTON/O.Q. 3101309',
#  '347067',
#  '349211',
#  'Harrow-on-the-Hill, Middlesex',
#  '113055',
#  'Indianapolis, IN',
#  'Coxon, Mr. Daniel',
#  'Andersson, Master. Sigvard Harald Elias',
#  'Chronopoulos, Mr. Demetrios',
#  '53',
#  '230433',
#  '11769',
#  'del Carlo, Mrs. Sebastiano (Argenia Genovesi)',
#  'Dahlberg, Miss. Gerda Ulrika',
#  'PC 17610',
#  'Guernsey / Elizabeth, NJ',
#  '6',
#  'Fortune, Miss. Alice Elizabeth',
#  'C97',
#  'Moscow / Bronx, NY',
#  'A31',
#  "Frost, Mr. Anthony Wood 'Archie'",
#  '4579',
#  'England Albion, NY',
#  '349253',
#  'Downton, Mr. William James',
#  'Harper, Rev. John',
#  'White, Mr. Percival Wayland',
#  'Allison, Mr. Hudson Joshua Creighton',
#  '103',
#  'St Andrews, Guernsey',
#  'Lemore, Mrs. (Amelia Milley)',
#  'Parr, Mr. William Henry Marsh',
#  '2620',
#  '11765',
#  'Berglund, Mr. Karl Ivar Sven',
#  '370129',
#  'SC 1748',
#  'Baclini, Miss. Eugenie',
#  'Eitemiller, Mr. George Floyd',
#  'C101',
#  '237671',
#  '349232',
#  'W./C. 14266',
#  '350052',
#  'Elkins Park, PA',
#  'PC 17608',
#  '17764',
#  'Coleridge, Mr. Reginald Charles',
#  'Karnes, Mrs. J Frank (Claire Bennett)',
#  'Moran, Mr. Daniel J',
#  'Farthing, Mr. John',
#  'de Pelsmaeker, Mr. Alfons',
#  '368702',
#  'Matinoff, Mr. Nicola',
#  '347078',
#  'West Kensington, London',
#  '7266',
#  '373450',
#  'Harrisburg, PA',
#  'D33',
#  'Geiger, Miss. Amalie',
#  'Cor, Mr. Bartol',
#  'Yousseff, Mr. Gerious',
#  'B28',
#  'Turpin, Mr. William John Robert',
#  'Kimball, Mrs. Edwin Nelson Jr (Gertrude Parsons)',
#  'Harknett, Miss. Alice Phoebe',
#  '111320',
#  'Landergren, Miss. Aurora Adelia',
#  '347091',
#  '350404',
#  '330923',
#  '122',
#  'STON/O2. 3101270',
#  'Green Bay, WI',
#  'Crosby, Capt. Edward Gifford',
#  'Bucknell, Mrs. William Robert (Emma Eliza Ward)',
#  'SC/PARIS 2159',
#  '15.5792',
#  'Pomeroy, WA',
#  'Sandstrom, Miss. Beatrice Irene',
#  'Osman, Mrs. Mara',
#  '324669',
#  '11778',
#  '348122',
#  'West Bromwich, England Pontiac, MI',
#  '36.75',
#  '0.3333',
#  'Frauenthal, Mrs. Henry William (Clara Heinsheimer)',
#  '347466',
#  'Bonnell, Miss. Caroline',
#  'Crafton, Mr. John Bertram',
#  'Bowenur, Mr. Solomon',
#  'Germantown, Philadelphia, PA',
#  '329944',
#  'Compton, Mr. Alexander Taylor Jr',
#  '17475',
#  'Bailey, Mr. Percy Andrew',
#  '2670',
#  'Fynney, Mr. Joseph J',
#  'Dorking, Surrey, England',
#  'Hickman, Mr. Stanley George',
#  'Mamaroneck, NY',
#  'Petroff, Mr. Nedelio',
#  'Harrison, Mr. William',
#  'Hiltunen, Miss. Marta',
#  'Todoroff, Mr. Lalio',
#  '248727',
#  'A24',
#  'B58 B60',
#  '16966',
#  'E58',
#  'C.A. 34260',
#  '0.1667',
#  '392096',
#  'PC 17591',
#  'Sadowitz, Mr. Harry',
#  '25.7417',
#  'Fischer, Mr. Eberhard Thelander',
#  'Laitinen, Miss. Kristina Sofia',
#  'Carbines, Mr. William',
#  '32',
#  '347089',
#  'Hunt, Mr. George Henry',
#  '126',
#  'Stead, Mr. William Thomas',
#  '32.3208',
#  'PC 17594',
#  'Phillips, Mr. Escott Robert',
#  '79.2',
#  'Ling, Mr. Lee',
#  'Balkic, Mr. Cerin',
#  'Goodwin, Master. Harold Victor',
#  '36963',
#  'Oslo, Norway Bayonne, NJ',
#  '29103',
#  '323951',
#  'North Evington, England',
#  'AQ/3. 30631',
#  '2672',
#  'Medeltorp, Sweden Chicago, IL',
#  'Harder, Mr. George Achilles',
#  "O'Driscoll, Miss. Bridget",
#  'PC 17760',
#  '237393',
#  'Denmark / New York, NY',
#  'New York, NY / Ithaca, NY',
#  'Emir, Mr. Farred Chehab',
#  'Jalsevac, Mr. Ivan',
#  '349202',
#  'Mt Airy, Philadelphia, PA',
#  'Bayside, Queens, NY',
#  'Sage, Mrs. John (Annie Bullen)',
#  '6.8583',
#  'Pengelly, Mr. Frederick William',
#  'Elizabeth, NJ',
#  'Harris, Mr. Walter',
#  '343120',
#  'Arnold-Franchi, Mrs. Josef (Josefine Franchi)',
#  'Oxenham, Mr. Percy Thomas',
#  'Sarnia, ON',
#  '111240',
#  'Icard, Miss. Amelie',
#  '7.75',
#  'PC 17582',
#  '7598',
#  'Kiernan, Mr. John',
#  '15 16',
#  'Gilinski, Mr. Eliezer',
#  'D',
#  '306',
#  'W./C. 14258',
#  '2679',
#  'B71',
#  '271',
#  '190',
#  'Dimic, Mr. Jovan',
#  'Laroche, Miss. Louise',
#  '3101295',
#  '113509',
#  'Isle of Wight, England',
#  'Vander Planke, Mr. Julius',
#  'Cornwall / Houghton, MI',
#  'Paris',
#  'C116',
#  '364851',
#  '26.25',
#  '312993',
#  'Brunswick, ME',
#  '364512',
#  'Roth, Miss. Sarah A',
#  'Youseff, Mr. Gerious',
#  'Wick, Mrs. George Dennick (Mary Hitchcock)',
#  'Sundman, Mr. Johan Julian',
#  '3474',
#  '13.4167',
#  "Rosenshine, Mr. George ('Mr George Thorne')",
#  'C2',
#  'Andersson, Miss. Ebba Iris Alfrida',
#  'Markun, Mr. Johann',
#  'Sunderland, Mr. Victor Francis',
#  '367655',
#  'B101',
#  'Lefebre, Master. Henry Forbes',
#  '9',
#  'Jussila, Miss. Katriina',
#  '38.5',
#  '330909',
#  'Rothes, the Countess. of (Lucy Noel Martha Dyer-Edwards)',
#  '113778',
#  'Ivanoff, Mr. Kanio',
#  'London  Vancouver, BC',
#  'C.A. 24580',
#  'Spain',
#  '7.7292',
#  '7',
#  '31.5',
#  'Sjostedt, Mr. Ernst Adolf',
#  '143',
#  'Rogers, Mr. William John',
#  '35',
#  'A/5. 2151',
#  'Pernot, Mr. Rene',
#  'Fillbrook, Mr. Joseph Charles',
#  'PC 17596',
#  'Collyer, Mr. Harvey',
#  'Doharr, Mr. Tannous',
#  '174',
#  'Stephenson, Mrs. Walter Bertram (Martha Eustis)',
#  'Stokes, Mr. Philip Joseph',
#  'Duquemin, Mr. Joseph',
#  'Deephaven, MN / Cedar Rapids, IA',
#  'Drapkin, Miss. Jennie',
#  'Nysten, Miss. Anna Sofia',
#  'Montevideo, Uruguay',
#  'Lefebre, Miss. Mathilde',
#  'Klasen, Miss. Gertrud Emilia',
#  'Swindon, England',
#  'Lexington, MA',
#  'Davies, Mr. Joseph',
#  '248698',
#  '153.4625',
#  'Risien, Mr. Samuel Beard',
#  '18.5',
#  '2686',
#  '370374',
#  'Pondersend, England / New Durham, NJ',
#  '349214',
#  'Harris, Mr. Henry Birkhardt',
#  'Gallagher, Mr. Martin',
#  '50',
#  'Spencer, Mrs. William Augustus (Marie Eugenie)',
#  'London Skanteales, NY',
#  '64',
#  '16.7',
#  'Kvillner, Mr. Johan Henrik Johannesson',
#  'Taylor, Mr. Elmer Zebley',
#  'Ayoub, Miss. Banoura',
#  'Scanlan, Mr. James',
#  'PC 17558',
#  'Mionoff, Mr. Stoytcho',
#  'Middleburg Heights, OH',
#  'Novel, Mr. Mansouer',
#  '371110',
#  "Troutt, Miss. Edwina Celia 'Winnie'",
#  'Davies, Mr. Evan',
#  'Lindell, Mr. Edvard Bengtsson',
#  '364500',
#  'PC 17590',
#  'Matthews, Mr. William John',
#  'Williams, Mr. Richard Norris II',
#  'Woolner, Mr. Hugh',
#  'Enander, Mr. Ingvar',
#  '42.4',
#  '29107',
#  '349215',
#  'Clevedon, England',
#  'Milling, Mr. Jacob Christian',
#  '315154',
#  '349228',
#  ...]

# %% [markdown]
# **Problem 7**
#
# Replace all '?' values in the DataFrame with np.nan values and write the resulting DataFrame to 'titanic_na.csv' file, making sure that the index of the DataFrame was not written in the file.

# %%
df.replace("?", np.nan, inplace=True)

# %%
df.to_csv("titanic_na.csv", index=False)

# %% [markdown]
# **Problem 8**
#
# Read "titanic_na.csv" as a DataFrame and output the number of NA values in each column of it.

# %%
df1 = pd.read_csv("titanic_na.csv")
df1.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
df1.isna().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %% [markdown]
# **Problem 9**
#
# Select all columns with even indices using iloc.

# %%
df1.iloc[:,::2]
# Out:
#       pclass                                             name      age  parch  \
# 0          1                    Allen, Miss. Elisabeth Walton  29.0000      0
# 1          1                   Allison, Master. Hudson Trevor   0.9167      2
# 2          1                     Allison, Miss. Helen Loraine   2.0000      2
# 3          1             Allison, Mr. Hudson Joshua Creighton  30.0000      2
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  25.0000      2
# ...      ...                                              ...      ...    ...
# 1304       3                             Zabour, Miss. Hileni  14.5000      0
# 1305       3                            Zabour, Miss. Thamine      NaN      0
# 1306       3                        Zakarian, Mr. Mapriededer  26.5000      0
# 1307       3                              Zakarian, Mr. Ortin  27.0000      0
# 1308       3                               Zimmerman, Mr. Leo  29.0000      0
#
#           fare embarked   body
# 0     211.3375        S    NaN
# 1     151.5500        S    NaN
# 2     151.5500        S    NaN
# 3     151.5500        S  135.0
# 4     151.5500        S    NaN
# ...        ...      ...    ...
# 1304   14.4542        C  328.0
# 1305   14.4542        C    NaN
# 1306    7.2250        C  304.0
# 1307    7.2250        C    NaN
# 1308    7.8750        S    NaN
#
# [1309 rows x 7 columns]

# %% [markdown]
# **Problem 10**
#
# Change the respective column names using the following dictionary {"pclass":"passanger_class", "sibsp":"sibling_spouse"}

# %%
df1.rename(columns={"pclass":"passanger_class", "sibsp":"sibling_spouse"}, inplace=True)

# %% [markdown]
# **Problem 11**
#
# Get the list of indices of the row(s) with largest fare value.

# %%
largest_value = df1.fare.max()

# %%
df1.fare[df1.fare == largest_value].index.tolist()
# Out:
# [49, 50, 183, 302]

# %% [markdown]
# **Problem 12**
#
# Select only the rows where the values of "ticket" columns are in the following list [24160,113781,2670]

# %%
df1[(df1.ticket == "24160") | (df1.ticket == "113781") | (df1.ticket == "2670")] #1st solution
# Out:
#       passanger_class  survived  \
# 0                   1         1
# 1                   1         1
# 2                   1         0
# 3                   1         0
# 4                   1         0
# 73                  1         1
# 88                  1         1
# 180                 1         1
# 193                 1         1
# 238                 1         1
# 1307                3         0
#
#                                                    name     sex      age  \
# 0                         Allen, Miss. Elisabeth Walton  female  29.0000
# 1                        Allison, Master. Hudson Trevor    male   0.9167
# 2                          Allison, Miss. Helen Loraine  female   2.0000
# 3                  Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000
# 73                                 Cleaver, Miss. Alice  female  22.0000
# 88                                 Daniels, Miss. Sarah  female  33.0000
# 180                              Kreuchen, Miss. Emilie  female  39.0000
# 193                   Madill, Miss. Georgette Alexandra  female  15.0000
# 238   Robert, Mrs. Edward Scott (Elisabeth Walton Mc...  female  43.0000
# 1307                                Zakarian, Mr. Ortin    male  27.0000
#
#       sibling_spouse  parch  ticket      fare    cabin embarked boat   body  \
# 0                  0      0   24160  211.3375       B5        S    2    NaN
# 1                  1      2  113781  151.5500  C22 C26        S   11    NaN
# 2                  1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3                  1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4                  1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 73                 0      0  113781  151.5500      NaN        S   11    NaN
# 88                 0      0  113781  151.5500      NaN        S    8    NaN
# 180                0      0   24160  211.3375      NaN        S    2    NaN
# 193                0      1   24160  211.3375       B5        S    2    NaN
# 238                0      1   24160  211.3375       B3        S    2    NaN
# 1307               0      0    2670    7.2250      NaN        C  NaN    NaN
#
#                             home.dest
# 0                        St Louis, MO
# 1     Montreal, PQ / Chesterville, ON
# 2     Montreal, PQ / Chesterville, ON
# 3     Montreal, PQ / Chesterville, ON
# 4     Montreal, PQ / Chesterville, ON
# 73                                NaN
# 88                                NaN
# 180                               NaN
# 193                      St Louis, MO
# 238                      St Louis, MO
# 1307                              NaN

# %%
df[df.ticket.isin(["24160","113781","2670"])] #2nd solution
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen, Miss. Elisabeth Walton
# 1          1         1                     Allison, Master. Hudson Trevor
# 2          1         0                       Allison, Miss. Helen Loraine
# 3          1         0               Allison, Mr. Hudson Joshua Creighton
# 4          1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 73         1         1                               Cleaver, Miss. Alice
# 88         1         1                               Daniels, Miss. Sarah
# 180        1         1                             Kreuchen, Miss. Emilie
# 193        1         1                  Madill, Miss. Georgette Alexandra
# 238        1         1  Robert, Mrs. Edward Scott (Elisabeth Walton Mc...
# 1307       3         0                                Zakarian, Mr. Ortin
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female      29      0      0   24160  211.3375       B5        S    2
# 1       male  0.9167      1      2  113781    151.55  C22 C26        S   11
# 2     female       2      1      2  113781    151.55  C22 C26        S  NaN
# 3       male      30      1      2  113781    151.55  C22 C26        S  NaN
# 4     female      25      1      2  113781    151.55  C22 C26        S  NaN
# 73    female      22      0      0  113781    151.55      NaN        S   11
# 88    female      33      0      0  113781    151.55      NaN        S    8
# 180   female      39      0      0   24160  211.3375      NaN        S    2
# 193   female      15      0      1   24160  211.3375       B5        S    2
# 238   female      43      0      1   24160  211.3375       B3        S    2
# 1307    male      27      0      0    2670     7.225      NaN        C  NaN
#
#      body                        home.dest
# 0     NaN                     St Louis, MO
# 1     NaN  Montreal, PQ / Chesterville, ON
# 2     NaN  Montreal, PQ / Chesterville, ON
# 3     135  Montreal, PQ / Chesterville, ON
# 4     NaN  Montreal, PQ / Chesterville, ON
# 73    NaN                              NaN
# 88    NaN                              NaN
# 180   NaN                              NaN
# 193   NaN                     St Louis, MO
# 238   NaN                     St Louis, MO
# 1307  NaN                              NaN

# %% [markdown]
# **Problem 13**
#
# Output the number of unique values, the list of unique values and value counts of age column. NA values must be counted too.

# %%
df1.age.nunique(dropna=False)
# Out:
# 99

# %%
print(list(df1.age.unique()))
# Out:
# [29.0, 0.9167, 2.0, 30.0, 25.0, 48.0, 63.0, 39.0, 53.0, 71.0, 47.0, 18.0, 24.0, 26.0, 80.0, nan, 50.0, 32.0, 36.0, 37.0, 42.0, 19.0, 35.0, 28.0, 45.0, 40.0, 58.0, 22.0, 41.0, 44.0, 59.0, 60.0, 33.0, 17.0, 11.0, 14.0, 49.0, 76.0, 46.0, 27.0, 64.0, 55.0, 70.0, 38.0, 51.0, 31.0, 4.0, 54.0, 23.0, 43.0, 52.0, 16.0, 32.5, 21.0, 15.0, 65.0, 28.5, 45.5, 56.0, 13.0, 61.0, 34.0, 6.0, 57.0, 62.0, 67.0, 1.0, 12.0, 20.0, 0.8333, 8.0, 0.6667, 7.0, 3.0, 36.5, 18.5, 5.0, 66.0, 9.0, 0.75, 70.5, 22.5, 0.3333, 0.1667, 40.5, 10.0, 23.5, 34.5, 20.5, 30.5, 55.5, 38.5, 14.5, 24.5, 60.5, 74.0, 0.4167, 11.5, 26.5]

# %%
df1.age.value_counts(dropna=False)
# Out:
# NaN        263
# 24.0000     47
# 22.0000     43
# 21.0000     41
# 30.0000     40
#           ...
# 24.5000      1
# 66.0000      1
# 22.5000      1
# 23.5000      1
# 0.6667       1
# Name: age, Length: 99, dtype: int64

# %% [markdown]
# **Problem 14**

# %% [markdown]
# Select all rows where column "cabin" contains characters 'C' or '6'.

# %%
df1[df1.cabin.str.contains(r"C|6", regex=True, na=False)]
# Out:
#       passanger_class  survived  \
# 1                   1         1
# 2                   1         0
# 3                   1         0
# 4                   1         0
# 7                   1         0
# ...               ...       ...
# 1187                3         1
# 1188                3         1
# 1189                3         1
# 1230                3         0
# 1231                3         0
#
#                                                    name     sex      age  \
# 1                        Allison, Master. Hudson Trevor    male   0.9167
# 2                          Allison, Miss. Helen Loraine  female   2.0000
# 3                  Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000
# 7                                Andrews, Mr. Thomas Jr    male  39.0000
# ...                                                 ...     ...      ...
# 1187                    Sandstrom, Miss. Beatrice Irene  female   1.0000
# 1188  Sandstrom, Mrs. Hjalmar (Agnes Charlotta Bengt...  female  24.0000
# 1189                    Sandstrom, Miss. Marguerite Rut  female   4.0000
# 1230                         Strom, Miss. Telma Matilda  female   2.0000
# 1231         Strom, Mrs. Wilhelm (Elna Matilda Persson)  female  29.0000
#
#       sibling_spouse  parch   ticket      fare    cabin embarked boat   body  \
# 1                  1      2   113781  151.5500  C22 C26        S   11    NaN
# 2                  1      2   113781  151.5500  C22 C26        S  NaN    NaN
# 3                  1      2   113781  151.5500  C22 C26        S  NaN  135.0
# 4                  1      2   113781  151.5500  C22 C26        S  NaN    NaN
# 7                  0      0   112050    0.0000      A36        S  NaN    NaN
# ...              ...    ...      ...       ...      ...      ...  ...    ...
# 1187               1      1  PP 9549   16.7000       G6        S   13    NaN
# 1188               0      2  PP 9549   16.7000       G6        S   13    NaN
# 1189               1      1  PP 9549   16.7000       G6        S   13    NaN
# 1230               0      1   347054   10.4625       G6        S  NaN    NaN
# 1231               1      1   347054   10.4625       G6        S  NaN    NaN
#
#                             home.dest
# 1     Montreal, PQ / Chesterville, ON
# 2     Montreal, PQ / Chesterville, ON
# 3     Montreal, PQ / Chesterville, ON
# 4     Montreal, PQ / Chesterville, ON
# 7                         Belfast, NI
# ...                               ...
# 1187                              NaN
# 1188                              NaN
# 1189                              NaN
# 1230                              NaN
# 1231                              NaN
#
# [141 rows x 14 columns]

# %% [markdown]
# **Problem 15**
#
# Drop duplicate rows from the the DataFrame.

# %%
df1.drop_duplicates(inplace=True)

# %% [markdown]
# **Problem 16**
#
# Select only rows where "name" column contains "Mrs." and "gender" column is male.

# %%
df1.loc[(df1.name.str.contains(r"Mrs.", regex=True)) & (df1.sex == "male")]
# Out:
# Empty DataFrame
# Columns: [passanger_class, survived, name, sex, age, sibling_spouse, parch, ticket, fare, cabin, embarked, boat, body, home.dest]
# Index: []

# %% [markdown]
# **Problem 17**
#
# Drop the home.dest column.

# %%
df1.drop("home.dest", axis="columns", inplace=True)

# %% [markdown]
# **Reset Changes**
#
# Read "titanic_na.csv" file to reset changes.

# %%
df1 = pd.read_csv("titanic_na.csv")
df1.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %% [markdown]
# **Problem 18**
#
# Replace Nan values in "age" column with the mean of that column.

# %%
mean_ = df1.age.mean()

# %%
df1.age.fillna(mean_, inplace=True)

# %% [markdown]
# **Problem 19**
#
# Output the mean age per home desintation.

# %%
df1.groupby("home.dest").age.mean()
# Out:
# home.dest
# ?Havana, Cuba                          28.500000
# Aberdeen / Portland, OR                26.000000
# Albany, NY                             31.000000
# Altdorf, Switzerland                   21.500000
# Amenia, ND                             46.500000
#                                          ...
# Worcester, England                     19.000000
# Worcester, MA                          37.000000
# Yoevil, England / Cottage Grove, OR    26.000000
# Youngstown, OH                         40.750000
# Zurich, Switzerland                    43.333333
# Name: age, Length: 369, dtype: float64

# %% [markdown]
# **Problem 20**
#
# Apply a lambda function on "cabin" column that will replace the values in the column with their first character, and nan values with the letter Z.

# %%
df1.cabin.apply(lambda x :x[0] if type(x) != float else "Z")
# Out:
# 0       B
# 1       C
# 2       C
# 3       C
# 4       C
#        ..
# 1304    Z
# 1305    Z
# 1306    Z
# 1307    Z
# 1308    Z
# Name: cabin, Length: 1309, dtype: object

# %% [markdown]
# **Problem 21**
#
# Replace each value in "name" column with the title in the name such as Mrs., Miss., Dona., Don. and so on. Replace it with "NOTITLE" string if ther is no title.
#
# **Hint:** You can use str.extract and regex to do that.

# %%
b =df1.name.str.extract(', (\w+.)', expand=False)
c = list(b)

# %%
for i,j in enumerate(c):
    if len(j) > 1: #which means regex pattern(title) was founded
        df1.name.values[i] = j
    else:
        df1.name.values[i] = "NOTITLE"

# %%
df1.head()
# Out:
#    pclass  survived     name     sex      age  sibsp  parch  ticket      fare  \
# 0       1         1    Miss.  female  29.0000      0      0   24160  211.3375
# 1       1         1  Master.    male   0.9167      1      2  113781  151.5500
# 2       1         0    Miss.  female   2.0000      1      2  113781  151.5500
# 3       1         0      Mr.    male  30.0000      1      2  113781  151.5500
# 4       1         0     Mrs.  female  25.0000      1      2  113781  151.5500
#
#      cabin embarked boat   body                        home.dest
# 0       B5        S    2    NaN                     St Louis, MO
# 1  C22 C26        S   11    NaN  Montreal, PQ / Chesterville, ON
# 2  C22 C26        S  NaN    NaN  Montreal, PQ / Chesterville, ON
# 3  C22 C26        S  NaN  135.0  Montreal, PQ / Chesterville, ON
# 4  C22 C26        S  NaN    NaN  Montreal, PQ / Chesterville, ON

# %% [markdown]
# **Problem 22**
#
# Replace the titles obtained during the previous step according to the below dictionary:
#
# {'Miss.': 0,
#  'Master.': 1,
#  'Mr.': 2,
#  'Mrs.': 3,
#  'Col.': 4,
#  'Mme.': 5,
#  'Dr.': 6,
#  'Major.': 7,
#  'Capt.': 8,
#  'Lady.': 9,
#  'Sir.': 10,
#  'Mlle.': 11,
#  'Dona.': 12,
#  'Jonkheer.': 13,
#  'Countess.': 14,
#  'Don.': 15,
#  'Rev.': 16,
#  'Ms.': 17}

# %%
df1.name = df1.name.map({'Miss.': 0, 'Master.': 1, 'Mr.': 2, 'Mrs.': 3, 'Col.': 4, 'Mme.': 5, 'Dr.': 6, 'Major.': 7, 'Capt.': 8, 'Lady.': 9, 'Sir.': 10, 'Mlle.': 11, 'Dona.': 12, 'Jonkheer.': 13, 'Countess.': 14, 'Don.': 15, 'Rev.': 16, 'Ms.': 17})

# %% [markdown]
# **Problem 23**
#
# Output the number of obeservations in each group based on the groupby operation of columns "pclass", "survived", and "sex" columns.

# %%
df1.groupby(["pclass", "survived", "sex"]).size()
# Out:
# pclass  survived  sex
# 1       0         female      5
#                   male      118
#         1         female    139
#                   male       61
# 2       0         female     12
#                   male      146
#         1         female     94
#                   male       25
# 3       0         female    110
#                   male      418
#         1         female    106
#                   male       75
# dtype: int64

# %% [markdown]
# **Problem 24**
#
# Output the maximum age of women for each title (column "name").

# %%
names_of_females = df1.name[df1.sex == "female"]

# %%
df1.groupby(names_of_females).age.max()
# Out:
# name
# 0.0     63.000000
# 3.0     76.000000
# 5.0     24.000000
# 6.0     49.000000
# 9.0     48.000000
# 11.0    24.000000
# 12.0    39.000000
# 17.0    29.881135
# Name: age, dtype: float64

# %% [markdown]
# **Problem 25**
#
# Merge below datasets based on "name" column, keeping all data.

# %%
df1 = pd.DataFrame(np.array([
    ['Fernando', 5, 9],
    ['Ursula', 4, 61],
    ['Marino', 24, 9]]),
    columns=['name', 'attr1', 'attr2'])
df2 = pd.DataFrame(np.array([
    ['Amoor', 5, 18],
    ['Mario', 14, 16],
    ['Bob', 4, 9]]),
    columns=['name', 'attr1', 'attr3'])

# %%
df1
# Out:
#        name attr1 attr2
# 0  Fernando     5     9
# 1    Ursula     4    61
# 2    Marino    24     9

# %%
df2
# Out:
#     name attr1 attr3
# 0  Amoor     5    18
# 1  Mario    14    16
# 2    Bob     4     9

# %%
pd.merge(df1, df2, on="name", how="outer")
# Out:
#        name attr1_x attr2 attr1_y attr3
# 0  Fernando       5     9     NaN   NaN
# 1    Ursula       4    61     NaN   NaN
# 2    Marino      24     9     NaN   NaN
# 3     Amoor     NaN   NaN       5    18
# 4     Mario     NaN   NaN      14    16
# 5       Bob     NaN   NaN       4     9

# %% [markdown]
# **Problem 26**
#
# Concatenate below datasets vertically.

# %%
df1 = pd.DataFrame(np.array([
    ['1', 5, 9],
    ['2', 4, 61],
    ['3', 24, 9]]),
    columns=['ind', 'attr1', 'attr2'])

df2 = pd.DataFrame(np.array([
    ['1', 5, 18],
    ['2', 14, 16],
    ['4', 4, 9]]),
    columns=['ind', 'attr1', 'attr2'])

# %%
df1
# Out:
#   ind attr1 attr2
# 0   1     5     9
# 1   2     4    61
# 2   3    24     9

# %%
df2
# Out:
#   ind attr1 attr2
# 0   1     5    18
# 1   2    14    16
# 2   4     4     9

# %%
pd.concat([df1, df2])
# Out:
#   ind attr1 attr2
# 0   1     5     9
# 1   2     4    61
# 2   3    24     9
# 0   1     5    18
# 1   2    14    16
# 2   4     4     9

# %% [markdown]
# **Problem 27**
#
# Use pivot table to calculate the mean age of male and female passengers who survived or died during the Titanic crash.

# %%
df.age = df.age.astype(float)
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2  NaN
# 1   0.9167      1      2  113781    151.55  C22 C26        S   11  NaN
# 2   2.0000      1      2  113781    151.55  C22 C26        S  NaN  NaN
# 3  30.0000      1      2  113781    151.55  C22 C26        S  NaN  135
# 4  25.0000      1      2  113781    151.55  C22 C26        S  NaN  NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
df.pivot_table(index="survived", columns="sex" , values="age", aggfunc="mean")
# Out:
# sex          female       male
# survived
# 0         25.255208  31.516412
# 1         29.815354  26.977778

# %% [markdown]
# **Problem 28**
#
# Do normalized crosstabulation for columns "survived" and "sex".

# %%
pd.crosstab(df.survived, df.sex, normalize=True)
# Out:
# sex         female      male
# survived
# 0         0.097021  0.521008
# 1         0.258976  0.122995

# %% [markdown]
# # Data Visualization

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# **Problem 29**
#
# Draw the plot below using matplotlib.
# ![plot1.png](plot1.png)

# %%
y = [5.0, 5.2, 5.4, 5.6, 5.8, 6.0]
x = y[::-1]
plt.plot(y, x)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# **Problem 30**
#
# Draw the plot below using matplotlib.
# ![plot2.png](plot2.png)

# %%
x1 = [0.0, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0, 3.5, 4.0]
y1 = [0.0, 1.0, 2.0, 3.0, 4.0, 3.0, 2.0, 1.0, 0.0]
plt.plot(x1,y1, label = "line1")

x2 = [0.0, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0, 3.5, 4.0]
y2 = [4.0, 3.0, 2.0, 1.0, 0.0, 1.0, 2.0, 3.0, 4.0]
plt.plot(x2, y2, label = "line2")
plt.legend()
plt.show()

# %% [markdown]
# **Problem 31**
#
# Read "passwords.csv" file into a DataFrame. You have a strange feeling that the larger the font_size paramter gets the higher is the strength of the password. Use pandas scatter plot to verify that idea.

# %%
df_ = pd.read_csv("passwords.csv")
df_.head()
# Out:
#    rank  password             category  value time_unit  offline_crack_sec  \
# 0   1.0  password     password-related   6.91     years       2.170000e+00
# 1   2.0    123456  simple-alphanumeric  18.52   minutes       1.110000e-05
# 2   3.0  12345678  simple-alphanumeric   1.29      days       1.110000e-03
# 3   4.0      1234  simple-alphanumeric  11.11   seconds       1.110000e-07
# 4   5.0    qwerty  simple-alphanumeric   3.72      days       3.210000e-03
#
#    rank_alt  strength  font_size
# 0       1.0       8.0       11.0
# 1       2.0       4.0        8.0
# 2       3.0       4.0        8.0
# 3       4.0       4.0        8.0
# 4       5.0       8.0       11.0

# %%
plt.scatter(df_.strength,df_.font_size)
plt.ylabel("Font_size")
plt.xlabel("Strength")
plt.title("Relationship between strength and font_size")
plt.show()

# %% [markdown]
# **Problem 32**
#
# You think that passwords containing integers have higher strength than passwords without integers. Verify your thought using seaborn's boxplot.

# %%
import re

# %%
for i, j in enumerate(df_.password.values):
    if re.findall(r"\d+", df_.password.values[i]) == []: # which means that the password does not have a digit in it
        df_.password.values[i] = "Passwords that do not contain integers"
    else:
        df_.password.values[i] = "Passwords that do contain integers"

# %%
sns.boxplot(y = df_["password"], x = df_["strength"])
# Out:
# <AxesSubplot:xlabel='strength', ylabel='password'>

# %% [markdown]
# # END
